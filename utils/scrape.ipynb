# %%
# %pip install pytest-playwright numpy pandas
# Out:
# Requirement already satisfied: pytest-playwright in /home/lebrancconvas/Project/Code/Side-Project/Data-Project/thai-ethnicity/.venv/lib/python3.12/site-packages (0.7.2)
# Requirement already satisfied: numpy in /home/lebrancconvas/Project/Code/Side-Project/Data-Project/thai-ethnicity/.venv/lib/python3.12/site-packages (2.4.4)
# Requirement already satisfied: pandas in /home/lebrancconvas/Project/Code/Side-Project/Data-Project/thai-ethnicity/.venv/lib/python3.12/site-packages (3.0.2)
# Requirement already satisfied: playwright>=1.18 in /home/lebrancconvas/Project/Code/Side-Project/Data-Project/thai-ethnicity/.venv/lib/python3.12/site-packages (from pytest-playwright) (1.58.0)
# Requirement already satisfied: pytest<10.0.0,>=6.2.4 in /home/lebrancconvas/Project/Code/Side-Project/Data-Project/thai-ethnicity/.venv/lib/python3.12/site-packages (from pytest-playwright) (9.0.2)
# Requirement already satisfied: pytest-base-url<3.0.0,>=1.0.0 in /home/lebrancconvas/Project/Code/Side-Project/Data-Project/thai-ethnicity/.venv/lib/python3.12/site-packages (from pytest-playwright) (2.1.0)
# Requirement already satisfied: python-slugify<9.0.0,>=6.0.0 in /home/lebrancconvas/Project/Code/Side-Project/Data-Project/thai-ethnicity/.venv/lib/python3.12/site-packages (from pytest-playwright) (8.0.4)
# Requirement already satisfied: iniconfig>=1.0.1 in /home/lebrancconvas/Project/Code/Side-Project/Data-Project/thai-ethnicity/.venv/lib/python3.12/site-packages (from pytest<10.0.0,>=6.2.4->pytest-playwright) (2.3.0)
# Requirement already satisfied: packaging>=22 in /home/lebrancconvas/Project/Code/Side-Project/Data-Project/thai-ethnicity/.venv/lib/python3.12/site-packages (from pytest<10.0.0,>=6.2.4->pytest-playwright) (26.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /home/lebrancconvas/Project/Code/Side-Project/Data-Project/thai-ethnicity/.venv/lib/python3.12/site-packages (from pytest<10.0.0,>=6.2.4->pytest-playwright) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /home/lebrancconvas/Project/Code/Side-Project/Data-Project/thai-ethnicity/.venv/lib/python3.12/site-packages (from pytest<10.0.0,>=6.2.4->pytest-playwright) (2.20.0)
# Requirement already satisfied: requests>=2.9 in /home/lebrancconvas/Project/Code/Side-Project/Data-Project/thai-ethnicity/.venv/lib/python3.12/site-packages (from pytest-base-url<3.0.0,>=1.0.0->pytest-playwright) (2.33.1)
# Requirement already satisfied: text-unidecode>=1.3 in /home/lebrancconvas/Project/Code/Side-Project/Data-Project/thai-ethnicity/.venv/lib/python3.12/site-packages (from python-slugify<9.0.0,>=6.0.0->pytest-playwright) (1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/lebrancconvas/Project/Code/Side-Project/Data-Project/thai-ethnicity/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pyee<14,>=13 in /home/lebrancconvas/Project/Code/Side-Project/Data-Project/thai-ethnicity/.venv/lib/python3.12/site-packages (from playwright>=1.18->pytest-playwright) (13.0.1)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in /home/lebrancconvas/Project/Code/Side-Project/Data-Project/thai-ethnicity/.venv/lib/python3.12/site-packages (from playwright>=1.18->pytest-playwright) (3.3.2)
# Requirement already satisfied: typing-extensions in /home/lebrancconvas/Project/Code/Side-Project/Data-Project/thai-ethnicity/.venv/lib/python3.12/site-packages (from pyee<14,>=13->playwright>=1.18->pytest-playwright) (4.15.0)
# Requirement already satisfied: six>=1.5 in /home/lebrancconvas/Project/Code/Side-Project/Data-Project/thai-ethnicity/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/lebrancconvas/Project/Code/Side-Project/Data-Project/thai-ethnicity/.venv/lib/python3.12/site-packages (from requests>=2.9->pytest-base-url<3.0.0,>=1.0.0->pytest-playwright) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /home/lebrancconvas/Project/Code/Side-Project/Data-Project/thai-ethnicity/.venv/lib/python3.12/site-packages (from requests>=2.9->pytest-base-url<3.0.0,>=1.0.0->pytest-playwright) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/lebrancconvas/Project/Code/Side-Project/Data-Project/thai-ethnicity/.venv/lib/python3.12/site-packages (from requests>=2.9->pytest-base-url<3.0.0,>=1.0.0->pytest-playwright) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /home/lebrancconvas/Project/Code/Side-Project/Data-Project/thai-ethnicity/.venv/lib/python3.12/site-packages (from requests>=2.9->pytest-base-url<3.0.0,>=1.0.0->pytest-playwright) (2026.2.25)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !playwright install

# %%
from playwright.sync_api import sync_playwright

# %%
BASE_URL = "https://ethnicity.sac.or.th/database-ethnic"

def run():
  with sync_playwright() as p:  
    browser = p.chromium.launch(headless=False)
    page = browser.new_page()
    page.goto(f"{BASE_URL}")
    # browser.close()

if __name__ == "__main__":
  run()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 11
#       7     page.goto(f"{BASE_URL}")
#       8     # browser.close()
#       9
#      10 if __name__ == "__main__":
# ---> 11   run()
#
# Cell In[16], line 4, in run()
#       3 def run():
# ----> 4   with async_playwright() as p:
#       5     browser = p.chromium.launch(headless=False)
#       6     page = browser.new_page()
#       7     page.goto(f"{BASE_URL}")
#
# TypeError: 'PlaywrightContextManager' object does not support the context manager protocol
